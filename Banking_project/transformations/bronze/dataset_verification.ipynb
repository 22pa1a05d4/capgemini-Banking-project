# %%
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("delimiter", ",") \
    .load("s3://manasa-banking-data/Initial_data/")

display(df)

# %%
# %sql
DROP TABLE bankingdatabase.bronze.transactions_bronze;
