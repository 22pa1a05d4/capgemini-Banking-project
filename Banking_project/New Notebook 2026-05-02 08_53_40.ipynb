# %%
# Load Silver Tables
txn = spark.read.table("bankingdatabase.silver.transactions_silver")
cust = spark.read.table("bankingdatabase.silver.customer_profile_silver")
sess = spark.read.table("bankingdatabase.silver.device_sessions_silver")

print(f"Transactions Count: {txn.count()}")
print(f"Customer Count: {cust.count()}")
print(f"Sessions Count: {sess.count()}")

txn.printSchema()
cust.printSchema()
sess.printSchema()
